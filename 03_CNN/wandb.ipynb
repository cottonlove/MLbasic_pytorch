# %% [markdown]
# #  Wandb Example
#
# visdom이 코랩에서 안되고 그닥 flexible하지 않은 거 같아서 걍 wandb실습으로!!!

# %%
import torch
import torch.nn as nn

import torchvision
import torchvision.datasets as dsets

# %% [markdown]
# **import wandb**

# %%
# !pip install wandb
# Out:
# ...
#      |████████████████████████████████| 1.7 MB 24.5 MB/s
# ...
#      |████████████████████████████████| 181 kB 69.6 MB/s
# ...
#      |████████████████████████████████| 144 kB 65.3 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.9 MB/s
# ...
# [Errno 99] Cannot assign requested address
# on_close() takes 1 positional argument but 3 were given
# ...
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=a2210d1bb6818c57e0be841c13e3fe430fd6365ca8859b461c646cccad5a15ce
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# ...
# [Errno 99] Cannot assign requested address
# on_close() takes 1 positional argument but 3 were given
# ...
